# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df_train = pd.read_csv("./train.csv/train.csv", parse_dates=['timestamp'])
df_test = pd.read_csv("./test.csv/test.csv", parse_dates=['timestamp'])
df_macro = pd.read_csv("./macro.csv", parse_dates=['timestamp'])
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# =============================
# =============================
# cleanup
# brings error down a lot by removing extreme price per sqm
print(df_train.shape)
df_train.loc[df_train.full_sq == 0, 'full_sq'] = 30
df_train = df_train[df_train.price_doc/df_train.full_sq <= 600000]
df_train = df_train[df_train.price_doc/df_train.full_sq >= 10000]
print(df_train.shape)
#print df_train.describe()
# =============================
# =============================

y_train =df_train['price_doc'].values
id_test = df_test['id']

df_train.drop(['id', 'price_doc'], axis=1, inplace=True)
df_test.drop(['id'], axis=1, inplace=True)

# Build df_all = (df_train+df_test).join(df_macro)
num_train = len(df_train)
df_all = pd.concat([df_train, df_test])
print df_all.shape
print df_all.columns
df_all = df_all.join(df_macro, on='timestamp', rsuffix='_macro')
print(df_all.shape)
print df_all.columns
# ==============================

# Add month-year
month_year = (df_all.timestamp.dt.month + df_all.timestamp.dt.year * 100)
month_year_cnt_map = month_year.value_counts().to_dict()
df_all['month_year_cnt'] = month_year.map(month_year_cnt_map)

# Add week-year count
week_year = (df_all.timestamp.dt.weekofyear + df_all.timestamp.dt.year * 100)
week_year_cnt_map = week_year.value_counts().to_dict()
df_all['week_year_cnt'] = week_year.map(week_year_cnt_map)

# Add month and day-of-week
df_all['month'] = df_all.timestamp.dt.month
df_all['dow'] = df_all.timestamp.dt.dayofweek

# Other feature engineering
df_all['rel_floor'] = df_all['floor'] / df_all['max_floor'].astype(float)
df_all['rel_kitch_sq'] = df_all['kitch_sq'] / df_all['full_sq'].astype(float)
#df_all["FAR"]=df_all["full_sq"]/df_all["area_m"].astype(float)
#df_all["ratio_life"]=((df_all["full_sq"]-df_all["kitch_sq"])/df_all["life_sq"]).astype(float)
df_all["inverse_floor"] = df_all["max_floor"]-df_all["floor"]
df_all["extra_area"] = df_all["full_sq"] - df_all["life_sq"]
df_all["room_size"] = (df_all["life_sq"] - df_all["kitch_sq"])/df_all["num_room"]
df_all["pop_density_raion"] = df_all["raion_popul"]/df_all["area_m"]
df_all["young_proportion"] =df_all["young_all"] / df_all["full_all"]
df_all["work_proportion"] = df_all["work_all"] / df_all["full_all"]
df_all["retire_proportion"] = df_all["ekder_all"] / df_all["full_all"]
df_all["ratio_preschool"] = df_all["children_school"] /df_all["preschool_quota"]
df_all["ratio_school"] = df_all["children_school"] / df_all["school_quota"]


#df_all["sqrt_area"] = np.sqrt(df_all["area_m"])
#df_all["log_full_sq"] = np.log(df_all["full_sq"])
#df_all["log_life_sq"] = np.log(df_all["life_sq"])
#df_all["log_kitch_sq"] = np.log(df_all["kitch_sq"])
#df_all["log_area_m"] = np.log(df_all["area_m"])
#df_all.drop(['full_sq','life_sq','kitch_sq','area_m'],axis=1,inplace=True)
#print df_all.loc[:,["sub_area","full_sq","life_sq","sqrt_area","area_m"]]

#df_all["st_mate"] = df_all["state"]*df_all["material"]
# Out:
# (30471, 292)
# (30404, 292)
# (38066, 290)
# Index([u'timestamp', u'full_sq', u'life_sq', u'floor', u'max_floor',
#        u'material', u'build_year', u'num_room', u'kitch_sq', u'state',
#        ...
#        u'cafe_count_5000_price_1500', u'cafe_count_5000_price_2500',
#        u'cafe_count_5000_price_4000', u'cafe_count_5000_price_high',
#        u'big_church_count_5000', u'church_count_5000', u'mosque_count_5000',
#        u'leisure_count_5000', u'sport_count_5000', u'market_count_5000'],
#       dtype='object', length=290)
# (38066, 390)
# Index([u'timestamp', u'full_sq', u'life_sq', u'floor', u'max_floor',
#        u'material', u'build_year', u'num_room', u'kitch_sq', u'state',
#        ...
#        u'provision_retail_space_modern_sqm', u'turnover_catering_per_cap',
#        u'theaters_viewers_per_1000_cap',
#        u'seats_theather_rfmin_per_100000_cap', u'museum_visitis_per_100_cap',
#        u'bandwidth_sports', u'population_reg_sports_share',
#        u'students_reg_sports_share', u'apartment_build',
#        u'apartment_fund_sqm'],
#       dtype='object', length=390)

# %%
#clean build_year
col = "build_year"
df_all[col].fillna(0,inplace=True)

df_all["build_year"] = df_all[df_all.build_year.values > 0]
ulimit = np.percentile(df_all[col].values, 99.995)
#llimit = np.percentile(df_all[col].values, 0.005)
df_all[col].ix[df_all[col]>ulimit] = ulimit
#df_all[col].ix[df_all[col]<llimit] = llimit
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#df_all["build_year"].describe()

#print df_all.loc[:,["build_count_before_1920","build_count_1921-1945","build_count_1946-1970","build_count_1971-1995","build_count_after_1995"]]

#df_all.loc[:,["timestamp","sub_area","raion_build_count_with_builddate_info","build_count_before_1920","build_count_1921-1945", "build_count_1946-1970","build_count_1971-1995","build_count_after_1995","build_year"]]

#df_all["room_area"] = ((df_all["life_sq"] - df_all["kitch_sq"])/df_all["num_room"]).astype(float)

#df_all.loc[:,["sub_area","raion_popul"]]

#df_all["raion_build_count_with_builddate_info"].describe([0.01,0.99])

# Remove timestamp column (may overfit the model in train)
df_all.drop(['timestamp', 'timestamp_macro'], axis=1, inplace=True)

factorize = lambda t: pd.factorize(t[1])[0]

df_obj = df_all.select_dtypes(include=['object'])

X_all = np.c_[
    df_all.select_dtypes(exclude=['object']).values,
    np.array(list(map(factorize, df_obj.iteritems()))).T
]
print(X_all.shape)

X_train = X_all[:num_train]
X_test = X_all[num_train:]


# Deal with categorical values
df_numeric = df_all.select_dtypes(exclude=['object'])
df_obj = df_all.select_dtypes(include=['object']).copy()

for c in df_obj:
    df_obj[c] = pd.factorize(df_obj[c])[0]

df_values = pd.concat([df_numeric, df_obj], axis=1)


# Convert to numpy values
X_all = df_values.values
print(X_all.shape)

X_train = X_all[:num_train]
X_test = X_all[num_train:]

df_columns = df_values.columns


xgb_params = {
    'eta': 0.05,
    'max_depth': 5,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
    #'alpha':0.001
}

dtrain = xgb.DMatrix(X_train, y_train, feature_names=df_columns)
dtest = xgb.DMatrix(X_test, feature_names=df_columns)


# Uncomment to tune XGB `num_boost_rounds`

cv_result = xgb.cv(xgb_params, dtrain, num_boost_round=1000, early_stopping_rounds=20,
    verbose_eval=True, show_stdv=False)
cv_result[['train-rmse-mean', 'test-rmse-mean']].plot()
num_boost_rounds = len(cv_result)

#num_boost_round = 489

model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=num_boost_round)

fig, ax = plt.subplots(1, 1, figsize=(8, 16))
xgb.plot_importance(model,height=0.5, ax=ax)
plt.show()

y_pred = model.predict(dtest)
y_pred = np.round(y_pred)
df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred})

df_sub.to_csv('sub_529_5.csv', index=False)
# Out:
# (38066, 403)
# (38066, 403)
# [0]	train-rmse:8.19435e+06	test-rmse:8.19944e+06
# [1]	train-rmse:7.83736e+06	test-rmse:7.85046e+06
# [2]	train-rmse:7.50098e+06	test-rmse:7.51954e+06
# [3]	train-rmse:7.184e+06	test-rmse:7.20724e+06
# [4]	train-rmse:6.89083e+06	test-rmse:6.92151e+06
# [5]	train-rmse:6.61005e+06	test-rmse:6.64875e+06
# [6]	train-rmse:6.33965e+06	test-rmse:6.38354e+06
# [7]	train-rmse:6.09071e+06	test-rmse:6.14106e+06
# [8]	train-rmse:5.85041e+06	test-rmse:5.90791e+06
# [9]	train-rmse:5.6292e+06	test-rmse:5.6944e+06
# [10]	train-rmse:5.41652e+06	test-rmse:5.49162e+06
# [11]	train-rmse:5.21437e+06	test-rmse:5.29802e+06
# [12]	train-rmse:5.0268e+06	test-rmse:5.11817e+06
# [13]	train-rmse:4.85504e+06	test-rmse:4.95317e+06
# [14]	train-rmse:4.69056e+06	test-rmse:4.79851e+06
# [15]	train-rmse:4.53338e+06	test-rmse:4.65021e+06
# [16]	train-rmse:4.3838e+06	test-rmse:4.51128e+06
# [17]	train-rmse:4.24332e+06	test-rmse:4.37704e+06
# [18]	train-rmse:4.11465e+06	test-rmse:4.25762e+06
# [19]	train-rmse:3.99147e+06	test-rmse:4.14439e+06
# [20]	train-rmse:3.87799e+06	test-rmse:4.0378e+06
# [21]	train-rmse:3.77131e+06	test-rmse:3.94232e+06
# [22]	train-rmse:3.66961e+06	test-rmse:3.85162e+06
# [23]	train-rmse:3.5736e+06	test-rmse:3.76456e+06
# [24]	train-rmse:3.48857e+06	test-rmse:3.68868e+06
# [25]	train-rmse:3.40627e+06	test-rmse:3.61435e+06
# [26]	train-rmse:3.32647e+06	test-rmse:3.54656e+06
# [27]	train-rmse:3.25478e+06	test-rmse:3.48553e+06
# [28]	train-rmse:3.18877e+06	test-rmse:3.42892e+06
# [29]	train-rmse:3.12471e+06	test-rmse:3.37486e+06
# [30]	train-rmse:3.06344e+06	test-rmse:3.32259e+06
# [31]	train-rmse:3.0064e+06	test-rmse:3.27438e+06
# [32]	train-rmse:2.95344e+06	test-rmse:3.22925e+06
# [33]	train-rmse:2.90383e+06	test-rmse:3.18706e+06
# [34]	train-rmse:2.85835e+06	test-rmse:3.15003e+06
# [35]	train-rmse:2.81746e+06	test-rmse:3.11698e+06
# [36]	train-rmse:2.77668e+06	test-rmse:3.08504e+06
# [37]	train-rmse:2.74127e+06	test-rmse:3.05742e+06
# [38]	train-rmse:2.70721e+06	test-rmse:3.03196e+06
# [39]	train-rmse:2.67288e+06	test-rmse:3.00599e+06
# [40]	train-rmse:2.64197e+06	test-rmse:2.98202e+06
# [41]	train-rmse:2.6145e+06	test-rmse:2.96014e+06
# [42]	train-rmse:2.58638e+06	test-rmse:2.93893e+06
# [43]	train-rmse:2.56254e+06	test-rmse:2.92178e+06
# [44]	train-rmse:2.53971e+06	test-rmse:2.90375e+06
# [45]	train-rmse:2.51866e+06	test-rmse:2.88788e+06
# [46]	train-rmse:2.49972e+06	test-rmse:2.87322e+06
# [47]	train-rmse:2.47985e+06	test-rmse:2.85907e+06
# [48]	train-rmse:2.46155e+06	test-rmse:2.84609e+06
# [49]	train-rmse:2.44503e+06	test-rmse:2.83523e+06
# [50]	train-rmse:2.43015e+06	test-rmse:2.82553e+06
# [51]	train-rmse:2.41571e+06	test-rmse:2.81433e+06
# [52]	train-rmse:2.40206e+06	test-rmse:2.8045e+06
# [53]	train-rmse:2.38737e+06	test-rmse:2.79603e+06
# [54]	train-rmse:2.37458e+06	test-rmse:2.78941e+06
# [55]	train-rmse:2.36297e+06	test-rmse:2.78164e+06
# [56]	train-rmse:2.35088e+06	test-rmse:2.77272e+06
# [57]	train-rmse:2.34069e+06	test-rmse:2.76484e+06
# [58]	train-rmse:2.32974e+06	test-rmse:2.75874e+06
# [59]	train-rmse:2.32075e+06	test-rmse:2.75271e+06
# [60]	train-rmse:2.3113e+06	test-rmse:2.74821e+06
# [61]	train-rmse:2.30129e+06	test-rmse:2.74248e+06
# [62]	train-rmse:2.29237e+06	test-rmse:2.7355e+06
# [63]	train-rmse:2.28263e+06	test-rmse:2.73085e+06
# [64]	train-rmse:2.2748e+06	test-rmse:2.72602e+06
# [65]	train-rmse:2.26709e+06	test-rmse:2.72167e+06
# [66]	train-rmse:2.26134e+06	test-rmse:2.71877e+06
# [67]	train-rmse:2.25495e+06	test-rmse:2.71557e+06
# [68]	train-rmse:2.24896e+06	test-rmse:2.71181e+06
# [69]	train-rmse:2.24286e+06	test-rmse:2.70924e+06
# [70]	train-rmse:2.23606e+06	test-rmse:2.70639e+06
# [71]	train-rmse:2.23022e+06	test-rmse:2.70317e+06
# [72]	train-rmse:2.22456e+06	test-rmse:2.69993e+06
# [73]	train-rmse:2.21972e+06	test-rmse:2.69816e+06
# [74]	train-rmse:2.21418e+06	test-rmse:2.69525e+06
# [75]	train-rmse:2.20874e+06	test-rmse:2.69222e+06
# [76]	train-rmse:2.20371e+06	test-rmse:2.69e+06
# [77]	train-rmse:2.19932e+06	test-rmse:2.68808e+06
# [78]	train-rmse:2.19459e+06	test-rmse:2.68515e+06
# [79]	train-rmse:2.19064e+06	test-rmse:2.68325e+06
# [80]	train-rmse:2.18577e+06	test-rmse:2.68001e+06
# [81]	train-rmse:2.18077e+06	test-rmse:2.67808e+06
# [82]	train-rmse:2.17676e+06	test-rmse:2.67656e+06
# [83]	train-rmse:2.17287e+06	test-rmse:2.6744e+06
# [84]	train-rmse:2.16865e+06	test-rmse:2.67237e+06
# [85]	train-rmse:2.16622e+06	test-rmse:2.67163e+06
# [86]	train-rmse:2.16235e+06	test-rmse:2.66996e+06
# [87]	train-rmse:2.15804e+06	test-rmse:2.6681e+06
# [88]	train-rmse:2.15499e+06	test-rmse:2.66576e+06
# [89]	train-rmse:2.15162e+06	test-rmse:2.66489e+06
# [90]	train-rmse:2.14858e+06	test-rmse:2.66364e+06
# [91]	train-rmse:2.14433e+06	test-rmse:2.66221e+06
# [92]	train-rmse:2.14149e+06	test-rmse:2.66111e+06
# [93]	train-rmse:2.1385e+06	test-rmse:2.65937e+06
# [94]	train-rmse:2.13589e+06	test-rmse:2.65863e+06
# [95]	train-rmse:2.13262e+06	test-rmse:2.65754e+06
# [96]	train-rmse:2.12864e+06	test-rmse:2.65607e+06
# [97]	train-rmse:2.12632e+06	test-rmse:2.6551e+06
# [98]	train-rmse:2.12292e+06	test-rmse:2.65379e+06
# [99]	train-rmse:2.12045e+06	test-rmse:2.6534e+06
# [100]	train-rmse:2.11757e+06	test-rmse:2.65223e+06
# [101]	train-rmse:2.11387e+06	test-rmse:2.65062e+06
# [102]	train-rmse:2.11116e+06	test-rmse:2.6491e+06
# [103]	train-rmse:2.10822e+06	test-rmse:2.64899e+06
# [104]	train-rmse:2.10587e+06	test-rmse:2.64775e+06
# [105]	train-rmse:2.10278e+06	test-rmse:2.64781e+06
# [106]	train-rmse:2.10014e+06	test-rmse:2.64654e+06
# [107]	train-rmse:2.09783e+06	test-rmse:2.64516e+06
# [108]	train-rmse:2.09642e+06	test-rmse:2.64456e+06
# [109]	train-rmse:2.09395e+06	test-rmse:2.64363e+06
# [110]	train-rmse:2.09103e+06	test-rmse:2.64243e+06
# [111]	train-rmse:2.08843e+06	test-rmse:2.64161e+06
# [112]	train-rmse:2.08571e+06	test-rmse:2.64089e+06
# [113]	train-rmse:2.08318e+06	test-rmse:2.64004e+06
# [114]	train-rmse:2.08086e+06	test-rmse:2.63937e+06
# [115]	train-rmse:2.07821e+06	test-rmse:2.63835e+06
# [116]	train-rmse:2.07542e+06	test-rmse:2.63795e+06
# [117]	train-rmse:2.07234e+06	test-rmse:2.63686e+06
# [118]	train-rmse:2.06993e+06	test-rmse:2.63589e+06
# [119]	train-rmse:2.06765e+06	test-rmse:2.63526e+06
# [120]	train-rmse:2.06475e+06	test-rmse:2.63465e+06
# [121]	train-rmse:2.06278e+06	test-rmse:2.63442e+06
# [122]	train-rmse:2.06012e+06	test-rmse:2.63353e+06
# [123]	train-rmse:2.05812e+06	test-rmse:2.63279e+06
# [124]	train-rmse:2.05647e+06	test-rmse:2.63255e+06
# [125]	train-rmse:2.05398e+06	test-rmse:2.63192e+06
# [126]	train-rmse:2.05166e+06	test-rmse:2.63123e+06
# [127]	train-rmse:2.04963e+06	test-rmse:2.63084e+06
# [128]	train-rmse:2.04799e+06	test-rmse:2.63034e+06
# [129]	train-rmse:2.04611e+06	test-rmse:2.62931e+06
# [130]	train-rmse:2.04487e+06	test-rmse:2.62847e+06
# [131]	train-rmse:2.04293e+06	test-rmse:2.62648e+06
# [132]	train-rmse:2.0404e+06	test-rmse:2.62502e+06
# [133]	train-rmse:2.03811e+06	test-rmse:2.62417e+06
# [134]	train-rmse:2.03641e+06	test-rmse:2.62381e+06
# [135]	train-rmse:2.03401e+06	test-rmse:2.62266e+06
# [136]	train-rmse:2.03122e+06	test-rmse:2.62232e+06
# [137]	train-rmse:2.02897e+06	test-rmse:2.62165e+06
# [138]	train-rmse:2.02727e+06	test-rmse:2.62168e+06
# [139]	train-rmse:2.02519e+06	test-rmse:2.62061e+06
# [140]	train-rmse:2.0229e+06	test-rmse:2.62003e+06
# [141]	train-rmse:2.02103e+06	test-rmse:2.61933e+06
# [142]	train-rmse:2.01933e+06	test-rmse:2.61843e+06
# [143]	train-rmse:2.01733e+06	test-rmse:2.61877e+06
# [144]	train-rmse:2.0157e+06	test-rmse:2.61826e+06
# [145]	train-rmse:2.01353e+06	test-rmse:2.61825e+06
# [146]	train-rmse:2.01101e+06	test-rmse:2.61757e+06
# [147]	train-rmse:2.00901e+06	test-rmse:2.61735e+06
# [148]	train-rmse:2.00728e+06	test-rmse:2.6169e+06
# [149]	train-rmse:2.00573e+06	test-rmse:2.61625e+06
# [150]	train-rmse:2.00356e+06	test-rmse:2.6153e+06
# [151]	train-rmse:2.00175e+06	test-rmse:2.61463e+06
# [152]	train-rmse:1.99935e+06	test-rmse:2.61378e+06
# [153]	train-rmse:1.99742e+06	test-rmse:2.61379e+06
# [154]	train-rmse:1.99588e+06	test-rmse:2.61340e+06
# [155]	train-rmse:1.99367e+06	test-rmse:2.6129e+06
# [156]	train-rmse:1.99226e+06	test-rmse:2.61253e+06
# [157]	train-rmse:1.98996e+06	test-rmse:2.61206e+06
# [158]	train-rmse:1.98802e+06	test-rmse:2.61189e+06
# [159]	train-rmse:1.98533e+06	test-rmse:2.61127e+06
# [160]	train-rmse:1.9839e+06	test-rmse:2.61066e+06
# [161]	train-rmse:1.98236e+06	test-rmse:2.61002e+06
# [162]	train-rmse:1.98026e+06	test-rmse:2.60967e+06
# [163]	train-rmse:1.97832e+06	test-rmse:2.6093e+06
# [164]	train-rmse:1.9767e+06	test-rmse:2.60896e+06
# [165]	train-rmse:1.97513e+06	test-rmse:2.60826e+06
# [166]	train-rmse:1.97307e+06	test-rmse:2.6076e+06
# [167]	train-rmse:1.9712e+06	test-rmse:2.60697e+06
# [168]	train-rmse:1.96911e+06	test-rmse:2.60708e+06
# [169]	train-rmse:1.96713e+06	test-rmse:2.60623e+06
# [170]	train-rmse:1.96529e+06	test-rmse:2.60579e+06
# [171]	train-rmse:1.96396e+06	test-rmse:2.60529e+06
# [172]	train-rmse:1.96236e+06	test-rmse:2.60515e+06
# [173]	train-rmse:1.96084e+06	test-rmse:2.60522e+06
# [174]	train-rmse:1.95933e+06	test-rmse:2.60486e+06
# [175]	train-rmse:1.9576e+06	test-rmse:2.60398e+06
# [176]	train-rmse:1.9555e+06	test-rmse:2.60377e+06
# [177]	train-rmse:1.95366e+06	test-rmse:2.60353e+06
# [178]	train-rmse:1.95216e+06	test-rmse:2.60322e+06
# [179]	train-rmse:1.95112e+06	test-rmse:2.60313e+06
# [180]	train-rmse:1.95023e+06	test-rmse:2.60314e+06
# [181]	train-rmse:1.9482e+06	test-rmse:2.60272e+06
# [182]	train-rmse:1.94663e+06	test-rmse:2.6029e+06
# [183]	train-rmse:1.94458e+06	test-rmse:2.60232e+06
# [184]	train-rmse:1.94366e+06	test-rmse:2.60233e+06
# [185]	train-rmse:1.94228e+06	test-rmse:2.60204e+06
# [186]	train-rmse:1.94029e+06	test-rmse:2.6023e+06
# [187]	train-rmse:1.93925e+06	test-rmse:2.60205e+06
# [188]	train-rmse:1.93781e+06	test-rmse:2.60169e+06
# [189]	train-rmse:1.93616e+06	test-rmse:2.60128e+06
# [190]	train-rmse:1.93519e+06	test-rmse:2.60103e+06
# [191]	train-rmse:1.93372e+06	test-rmse:2.60052e+06
# [192]	train-rmse:1.9323e+06	test-rmse:2.60028e+06
# [193]	train-rmse:1.93093e+06	test-rmse:2.59955e+06
# [194]	train-rmse:1.92934e+06	test-rmse:2.5995e+06
# [195]	train-rmse:1.92787e+06	test-rmse:2.59912e+06
# [196]	train-rmse:1.92663e+06	test-rmse:2.59878e+06
# [197]	train-rmse:1.9258e+06	test-rmse:2.59847e+06
# [198]	train-rmse:1.92452e+06	test-rmse:2.59806e+06
# [199]	train-rmse:1.92254e+06	test-rmse:2.59761e+06
# [200]	train-rmse:1.9214e+06	test-rmse:2.59722e+06
# [201]	train-rmse:1.91989e+06	test-rmse:2.59689e+06
# [202]	train-rmse:1.91862e+06	test-rmse:2.59673e+06
# [203]	train-rmse:1.91683e+06	test-rmse:2.5963e+06
# [204]	train-rmse:1.91515e+06	test-rmse:2.59609e+06
# [205]	train-rmse:1.91366e+06	test-rmse:2.59581e+06
# [206]	train-rmse:1.91177e+06	test-rmse:2.59575e+06
# [207]	train-rmse:1.91009e+06	test-rmse:2.59617e+06
# [208]	train-rmse:1.90863e+06	test-rmse:2.59632e+06
# [209]	train-rmse:1.90686e+06	test-rmse:2.59628e+06
# [210]	train-rmse:1.9048e+06	test-rmse:2.59575e+06
# [211]	train-rmse:1.90359e+06	test-rmse:2.5955e+06
# [212]	train-rmse:1.90234e+06	test-rmse:2.59497e+06
# [213]	train-rmse:1.90021e+06	test-rmse:2.59409e+06
# [214]	train-rmse:1.89799e+06	test-rmse:2.59372e+06
# [215]	train-rmse:1.89586e+06	test-rmse:2.59406e+06
# [216]	train-rmse:1.89477e+06	test-rmse:2.59405e+06
# [217]	train-rmse:1.89266e+06	test-rmse:2.5942e+06
# [218]	train-rmse:1.89078e+06	test-rmse:2.59385e+06
# [219]	train-rmse:1.88987e+06	test-rmse:2.59386e+06
# [220]	train-rmse:1.88813e+06	test-rmse:2.59335e+06
# [221]	train-rmse:1.88678e+06	test-rmse:2.59359e+06
# [222]	train-rmse:1.88562e+06	test-rmse:2.59352e+06
# [223]	train-rmse:1.88453e+06	test-rmse:2.59306e+06
# [224]	train-rmse:1.88314e+06	test-rmse:2.59289e+06
# [225]	train-rmse:1.88185e+06	test-rmse:2.59293e+06
# [226]	train-rmse:1.88058e+06	test-rmse:2.59264e+06
# [227]	train-rmse:1.87869e+06	test-rmse:2.59211e+06
# [228]	train-rmse:1.87772e+06	test-rmse:2.5916e+06
# [229]	train-rmse:1.87629e+06	test-rmse:2.59123e+06
# [230]	train-rmse:1.87476e+06	test-rmse:2.59091e+06
# [231]	train-rmse:1.87328e+06	test-rmse:2.5907e+06
# [232]	train-rmse:1.87202e+06	test-rmse:2.59075e+06
# [233]	train-rmse:1.87083e+06	test-rmse:2.59047e+06
# [234]	train-rmse:1.86979e+06	test-rmse:2.5901e+06
# [235]	train-rmse:1.86798e+06	test-rmse:2.59002e+06
# [236]	train-rmse:1.8665e+06	test-rmse:2.58983e+06
# [237]	train-rmse:1.86548e+06	test-rmse:2.58946e+06
# [238]	train-rmse:1.86446e+06	test-rmse:2.5895e+06
# [239]	train-rmse:1.86351e+06	test-rmse:2.58896e+06
# [240]	train-rmse:1.86208e+06	test-rmse:2.58883e+06
# [241]	train-rmse:1.85977e+06	test-rmse:2.58884e+06
# [242]	train-rmse:1.85805e+06	test-rmse:2.58862e+06
# [243]	train-rmse:1.85674e+06	test-rmse:2.58822e+06
# [244]	train-rmse:1.85536e+06	test-rmse:2.5883e+06
# [245]	train-rmse:1.85428e+06	test-rmse:2.58846e+06
# [246]	train-rmse:1.85297e+06	test-rmse:2.58794e+06
# [247]	train-rmse:1.85178e+06	test-rmse:2.58803e+06
# [248]	train-rmse:1.85047e+06	test-rmse:2.58787e+06
# [249]	train-rmse:1.84887e+06	test-rmse:2.58759e+06
# [250]	train-rmse:1.84758e+06	test-rmse:2.58761e+06
# [251]	train-rmse:1.84596e+06	test-rmse:2.58759e+06
# [252]	train-rmse:1.84482e+06	test-rmse:2.58731e+06
# [253]	train-rmse:1.84362e+06	test-rmse:2.58709e+06
# [254]	train-rmse:1.84268e+06	test-rmse:2.5869e+06
# [255]	train-rmse:1.84118e+06	test-rmse:2.58684e+06
# [256]	train-rmse:1.83975e+06	test-rmse:2.58636e+06
# [257]	train-rmse:1.83858e+06	test-rmse:2.5865e+06
# [258]	train-rmse:1.83712e+06	test-rmse:2.58636e+06
# [259]	train-rmse:1.83566e+06	test-rmse:2.58601e+06
# [260]	train-rmse:1.83424e+06	test-rmse:2.58581e+06
# [261]	train-rmse:1.83306e+06	test-rmse:2.58581e+06
# [262]	train-rmse:1.83147e+06	test-rmse:2.58526e+06
# [263]	train-rmse:1.83041e+06	test-rmse:2.58501e+06
# [264]	train-rmse:1.82953e+06	test-rmse:2.58495e+06
# [265]	train-rmse:1.82823e+06	test-rmse:2.58481e+06
# [266]	train-rmse:1.82691e+06	test-rmse:2.5846e+06
# [267]	train-rmse:1.82544e+06	test-rmse:2.58451e+06
# [268]	train-rmse:1.8244e+06	test-rmse:2.58423e+06
# [269]	train-rmse:1.82326e+06	test-rmse:2.58404e+06
# [270]	train-rmse:1.82226e+06	test-rmse:2.58442e+06
# [271]	train-rmse:1.82076e+06	test-rmse:2.58447e+06
# [272]	train-rmse:1.81976e+06	test-rmse:2.58432e+06
# [273]	train-rmse:1.81838e+06	test-rmse:2.58432e+06
# [274]	train-rmse:1.81696e+06	test-rmse:2.58424e+06
# [275]	train-rmse:1.8159e+06	test-rmse:2.58404e+06
# [276]	train-rmse:1.81473e+06	test-rmse:2.58398e+06
# [277]	train-rmse:1.81376e+06	test-rmse:2.58425e+06
# [278]	train-rmse:1.8122e+06	test-rmse:2.58423e+06
# [279]	train-rmse:1.81043e+06	test-rmse:2.58433e+06
# [280]	train-rmse:1.80866e+06	test-rmse:2.58382e+06
# [281]	train-rmse:1.80756e+06	test-rmse:2.58344e+06
# [282]	train-rmse:1.80612e+06	test-rmse:2.58345e+06
# [283]	train-rmse:1.80533e+06	test-rmse:2.58336e+06
# [284]	train-rmse:1.80413e+06	test-rmse:2.58343e+06
# [285]	train-rmse:1.80253e+06	test-rmse:2.58347e+06
# [286]	train-rmse:1.80175e+06	test-rmse:2.5834e+06
# [287]	train-rmse:1.80051e+06	test-rmse:2.58328e+06
# [288]	train-rmse:1.79919e+06	test-rmse:2.58301e+06
# [289]	train-rmse:1.79778e+06	test-rmse:2.58283e+06
# [290]	train-rmse:1.79667e+06	test-rmse:2.58213e+06
# [291]	train-rmse:1.7954e+06	test-rmse:2.58205e+06
# [292]	train-rmse:1.79453e+06	test-rmse:2.5819e+06
# [293]	train-rmse:1.79335e+06	test-rmse:2.58177e+06
# [294]	train-rmse:1.79223e+06	test-rmse:2.58204e+06
# [295]	train-rmse:1.79118e+06	test-rmse:2.58209e+06
# [296]	train-rmse:1.79005e+06	test-rmse:2.58251e+06
# [297]	train-rmse:1.78893e+06	test-rmse:2.58249e+06
# [298]	train-rmse:1.78784e+06	test-rmse:2.58229e+06
# [299]	train-rmse:1.78636e+06	test-rmse:2.58184e+06
# [300]	train-rmse:1.78529e+06	test-rmse:2.58178e+06
# [301]	train-rmse:1.7841e+06	test-rmse:2.58171e+06
# [302]	train-rmse:1.78255e+06	test-rmse:2.58154e+06
# [303]	train-rmse:1.78141e+06	test-rmse:2.58129e+06
# [304]	train-rmse:1.78032e+06	test-rmse:2.58112e+06
# [305]	train-rmse:1.77889e+06	test-rmse:2.58106e+06
# [306]	train-rmse:1.77778e+06	test-rmse:2.58103e+06
# [307]	train-rmse:1.77658e+06	test-rmse:2.58112e+06
# [308]	train-rmse:1.77512e+06	test-rmse:2.58108e+06
# [309]	train-rmse:1.77346e+06	test-rmse:2.58078e+06
# [310]	train-rmse:1.77231e+06	test-rmse:2.58064e+06
# [311]	train-rmse:1.77123e+06	test-rmse:2.58077e+06
# [312]	train-rmse:1.76995e+06	test-rmse:2.58083e+06
# [313]	train-rmse:1.76896e+06	test-rmse:2.58077e+06
# [314]	train-rmse:1.76776e+06	test-rmse:2.58055e+06
# [315]	train-rmse:1.76682e+06	test-rmse:2.58045e+06
# [316]	train-rmse:1.76521e+06	test-rmse:2.58033e+06
# [317]	train-rmse:1.76436e+06	test-rmse:2.58051e+06
# [318]	train-rmse:1.76351e+06	test-rmse:2.58083e+06
# [319]	train-rmse:1.76289e+06	test-rmse:2.58082e+06
# [320]	train-rmse:1.76205e+06	test-rmse:2.58076e+06
# [321]	train-rmse:1.76075e+06	test-rmse:2.58071e+06
# [322]	train-rmse:1.75999e+06	test-rmse:2.58062e+06
# [323]	train-rmse:1.75874e+06	test-rmse:2.58049e+06
# [324]	train-rmse:1.75807e+06	test-rmse:2.5804e+06
# [325]	train-rmse:1.7574e+06	test-rmse:2.58042e+06
# [326]	train-rmse:1.75617e+06	test-rmse:2.58035e+06
# [327]	train-rmse:1.75475e+06	test-rmse:2.58033e+06
# [328]	train-rmse:1.75366e+06	test-rmse:2.58008e+06
# [329]	train-rmse:1.75272e+06	test-rmse:2.58013e+06
# [330]	train-rmse:1.75198e+06	test-rmse:2.58046e+06
# [331]	train-rmse:1.75136e+06	test-rmse:2.58033e+06
# [332]	train-rmse:1.75028e+06	test-rmse:2.58018e+06
# [333]	train-rmse:1.74935e+06	test-rmse:2.58007e+06
# [334]	train-rmse:1.74838e+06	test-rmse:2.57985e+06
# [335]	train-rmse:1.74738e+06	test-rmse:2.57969e+06
# [336]	train-rmse:1.74637e+06	test-rmse:2.57964e+06
# [337]	train-rmse:1.74505e+06	test-rmse:2.57959e+06
# [338]	train-rmse:1.74402e+06	test-rmse:2.57952e+06
# [339]	train-rmse:1.74255e+06	test-rmse:2.57955e+06
# [340]	train-rmse:1.74143e+06	test-rmse:2.57968e+06
# [341]	train-rmse:1.74015e+06	test-rmse:2.57939e+06
# [342]	train-rmse:1.7392e+06	test-rmse:2.57941e+06
# [343]	train-rmse:1.7379e+06	test-rmse:2.57936e+06
# [344]	train-rmse:1.73707e+06	test-rmse:2.57927e+06
# [345]	train-rmse:1.73574e+06	test-rmse:2.57907e+06
# [346]	train-rmse:1.73479e+06	test-rmse:2.5789e+06
# [347]	train-rmse:1.73363e+06	test-rmse:2.57889e+06
# [348]	train-rmse:1.73254e+06	test-rmse:2.57871e+06
# [349]	train-rmse:1.73169e+06	test-rmse:2.57882e+06
# [350]	train-rmse:1.73055e+06	test-rmse:2.57854e+06
# [351]	train-rmse:1.72946e+06	test-rmse:2.57832e+06
# [352]	train-rmse:1.7286e+06	test-rmse:2.57834e+06
# [353]	train-rmse:1.7272e+06	test-rmse:2.57825e+06
# [354]	train-rmse:1.72638e+06	test-rmse:2.57788e+06
# [355]	train-rmse:1.72546e+06	test-rmse:2.57784e+06
# [356]	train-rmse:1.72442e+06	test-rmse:2.57799e+06
# [357]	train-rmse:1.72329e+06	test-rmse:2.57823e+06
# [358]	train-rmse:1.72217e+06	test-rmse:2.57798e+06
# [359]	train-rmse:1.72102e+06	test-rmse:2.57742e+06
# [360]	train-rmse:1.71993e+06	test-rmse:2.57745e+06
# [361]	train-rmse:1.71883e+06	test-rmse:2.57723e+06
# [362]	train-rmse:1.71817e+06	test-rmse:2.57719e+06
# [363]	train-rmse:1.71703e+06	test-rmse:2.57734e+06
# [364]	train-rmse:1.71563e+06	test-rmse:2.57728e+06
# [365]	train-rmse:1.71474e+06	test-rmse:2.5772e+06
# [366]	train-rmse:1.714e+06	test-rmse:2.57735e+06
# [367]	train-rmse:1.71258e+06	test-rmse:2.57724e+06
# [368]	train-rmse:1.71149e+06	test-rmse:2.5772e+06
# [369]	train-rmse:1.71028e+06	test-rmse:2.57684e+06
# [370]	train-rmse:1.7093e+06	test-rmse:2.57685e+06
# [371]	train-rmse:1.70817e+06	test-rmse:2.57682e+06
# [372]	train-rmse:1.70731e+06	test-rmse:2.57669e+06
# [373]	train-rmse:1.70633e+06	test-rmse:2.57674e+06
# [374]	train-rmse:1.70515e+06	test-rmse:2.57661e+06
# [375]	train-rmse:1.70425e+06	test-rmse:2.57654e+06
# [376]	train-rmse:1.70355e+06	test-rmse:2.57659e+06
# [377]	train-rmse:1.70217e+06	test-rmse:2.57647e+06
# [378]	train-rmse:1.70103e+06	test-rmse:2.57632e+06
# [379]	train-rmse:1.70008e+06	test-rmse:2.5764e+06
# [380]	train-rmse:1.69901e+06	test-rmse:2.57647e+06
# [381]	train-rmse:1.69785e+06	test-rmse:2.57619e+06
# [382]	train-rmse:1.6968e+06	test-rmse:2.57617e+06
# [383]	train-rmse:1.69555e+06	test-rmse:2.57615e+06
# [384]	train-rmse:1.69467e+06	test-rmse:2.57615e+06
# [385]	train-rmse:1.69306e+06	test-rmse:2.57656e+06
# [386]	train-rmse:1.69216e+06	test-rmse:2.57655e+06
# [387]	train-rmse:1.69145e+06	test-rmse:2.57652e+06
# [388]	train-rmse:1.69042e+06	test-rmse:2.57665e+06
# [389]	train-rmse:1.68917e+06	test-rmse:2.57655e+06
# [390]	train-rmse:1.68794e+06	test-rmse:2.57656e+06
# [391]	train-rmse:1.68714e+06	test-rmse:2.57638e+06
# [392]	train-rmse:1.68637e+06	test-rmse:2.57638e+06
# [393]	train-rmse:1.68548e+06	test-rmse:2.57642e+06
# [394]	train-rmse:1.68422e+06	test-rmse:2.57634e+06
# [395]	train-rmse:1.68303e+06	test-rmse:2.57647e+06
# [396]	train-rmse:1.68172e+06	test-rmse:2.57643e+06
# [397]	train-rmse:1.68116e+06	test-rmse:2.57626e+06
# [398]	train-rmse:1.68032e+06	test-rmse:2.5762e+06
# [399]	train-rmse:1.67963e+06	test-rmse:2.57602e+06
# [400]	train-rmse:1.67821e+06	test-rmse:2.57577e+06
# [401]	train-rmse:1.67665e+06	test-rmse:2.57547e+06
# [402]	train-rmse:1.67534e+06	test-rmse:2.57507e+06
# [403]	train-rmse:1.67469e+06	test-rmse:2.57494e+06
# [404]	train-rmse:1.67379e+06	test-rmse:2.57517e+06
# [405]	train-rmse:1.67301e+06	test-rmse:2.57511e+06
# [406]	train-rmse:1.67208e+06	test-rmse:2.57493e+06
# [407]	train-rmse:1.67124e+06	test-rmse:2.57492e+06
# [408]	train-rmse:1.67044e+06	test-rmse:2.57495e+06
# [409]	train-rmse:1.6698e+06	test-rmse:2.57493e+06
# [410]	train-rmse:1.66886e+06	test-rmse:2.57507e+06
# [411]	train-rmse:1.66784e+06	test-rmse:2.57525e+06
# [412]	train-rmse:1.66689e+06	test-rmse:2.5751e+06
# [413]	train-rmse:1.66612e+06	test-rmse:2.57507e+06
# [414]	train-rmse:1.66516e+06	test-rmse:2.5751e+06
# [415]	train-rmse:1.6642e+06	test-rmse:2.57534e+06
# [416]	train-rmse:1.66319e+06	test-rmse:2.57528e+06
# [417]	train-rmse:1.66233e+06	test-rmse:2.57541e+06
# [418]	train-rmse:1.66133e+06	test-rmse:2.57559e+06
# [419]	train-rmse:1.66039e+06	test-rmse:2.57576e+06
# [420]	train-rmse:1.6595e+06	test-rmse:2.57572e+06
# [421]	train-rmse:1.65847e+06	test-rmse:2.57561e+06
# [422]	train-rmse:1.65765e+06	test-rmse:2.5758e+06
# [423]	train-rmse:1.65671e+06	test-rmse:2.5756e+06
# [424]	train-rmse:1.65573e+06	test-rmse:2.57557e+06
# [425]	train-rmse:1.65489e+06	test-rmse:2.57524e+06
# [426]	train-rmse:1.65406e+06	test-rmse:2.57491e+06
# [427]	train-rmse:1.65291e+06	test-rmse:2.5748e+06
# [428]	train-rmse:1.65192e+06	test-rmse:2.57461e+06
# [429]	train-rmse:1.65084e+06	test-rmse:2.57484e+06
# [430]	train-rmse:1.65009e+06	test-rmse:2.57515e+06
# [431]	train-rmse:1.649e+06	test-rmse:2.57517e+06
# [432]	train-rmse:1.64788e+06	test-rmse:2.57523e+06
# [433]	train-rmse:1.64733e+06	test-rmse:2.57527e+06
# [434]	train-rmse:1.64635e+06	test-rmse:2.57501e+06
# [435]	train-rmse:1.64519e+06	test-rmse:2.57492e+06
# [436]	train-rmse:1.64395e+06	test-rmse:2.5747e+06
# [437]	train-rmse:1.64304e+06	test-rmse:2.57451e+06
# [438]	train-rmse:1.64196e+06	test-rmse:2.57442e+06
# [439]	train-rmse:1.64134e+06	test-rmse:2.57464e+06
# [440]	train-rmse:1.64063e+06	test-rmse:2.57481e+06
# [441]	train-rmse:1.64009e+06	test-rmse:2.57469e+06
# [442]	train-rmse:1.63884e+06	test-rmse:2.57436e+06
# [443]	train-rmse:1.63761e+06	test-rmse:2.57437e+06
# [444]	train-rmse:1.63667e+06	test-rmse:2.57421e+06
# [445]	train-rmse:1.63572e+06	test-rmse:2.57448e+06
# [446]	train-rmse:1.63463e+06	test-rmse:2.57444e+06
# [447]	train-rmse:1.63388e+06	test-rmse:2.57428e+06
# [448]	train-rmse:1.63275e+06	test-rmse:2.57432e+06
# [449]	train-rmse:1.63142e+06	test-rmse:2.57434e+06
# [450]	train-rmse:1.63068e+06	test-rmse:2.57421e+06
# [451]	train-rmse:1.6297e+06	test-rmse:2.57405e+06
# [452]	train-rmse:1.62873e+06	test-rmse:2.57397e+06
# [453]	train-rmse:1.6281e+06	test-rmse:2.57372e+06
# [454]	train-rmse:1.62736e+06	test-rmse:2.57374e+06
# [455]	train-rmse:1.62682e+06	test-rmse:2.57371e+06
# [456]	train-rmse:1.62576e+06	test-rmse:2.57356e+06
# [457]	train-rmse:1.62468e+06	test-rmse:2.57359e+06
# [458]	train-rmse:1.62401e+06	test-rmse:2.57353e+06
# [459]	train-rmse:1.62314e+06	test-rmse:2.57351e+06
# [460]	train-rmse:1.62229e+06	test-rmse:2.57364e+06
# [461]	train-rmse:1.62151e+06	test-rmse:2.57372e+06
# [462]	train-rmse:1.62039e+06	test-rmse:2.57405e+06
# [463]	train-rmse:1.61958e+06	test-rmse:2.57414e+06
# [464]	train-rmse:1.61883e+06	test-rmse:2.57398e+06
# [465]	train-rmse:1.61789e+06	test-rmse:2.57399e+06
# [466]	train-rmse:1.61692e+06	test-rmse:2.57397e+06
# [467]	train-rmse:1.61638e+06	test-rmse:2.57376e+06
# [468]	train-rmse:1.61558e+06	test-rmse:2.57371e+06
# [469]	train-rmse:1.61467e+06	test-rmse:2.5734e+06
# [470]	train-rmse:1.61375e+06	test-rmse:2.57345e+06
# [471]	train-rmse:1.61305e+06	test-rmse:2.57327e+06
# [472]	train-rmse:1.61221e+06	test-rmse:2.57347e+06
# [473]	train-rmse:1.61161e+06	test-rmse:2.57349e+06
# [474]	train-rmse:1.61064e+06	test-rmse:2.57347e+06
# [475]	train-rmse:1.60952e+06	test-rmse:2.57376e+06
# [476]	train-rmse:1.60873e+06	test-rmse:2.57363e+06
# [477]	train-rmse:1.608e+06	test-rmse:2.57344e+06
# [478]	train-rmse:1.60703e+06	test-rmse:2.57323e+06
# [479]	train-rmse:1.60593e+06	test-rmse:2.57324e+06
# [480]	train-rmse:1.60519e+06	test-rmse:2.57334e+06
# [481]	train-rmse:1.60415e+06	test-rmse:2.57353e+06
# [482]	train-rmse:1.60329e+06	test-rmse:2.57341e+06
# [483]	train-rmse:1.60251e+06	test-rmse:2.57348e+06
# [484]	train-rmse:1.60162e+06	test-rmse:2.57338e+06
# [485]	train-rmse:1.6009e+06	test-rmse:2.57331e+06
# [486]	train-rmse:1.60013e+06	test-rmse:2.57332e+06
# [487]	train-rmse:1.59907e+06	test-rmse:2.57334e+06
# [488]	train-rmse:1.59846e+06	test-rmse:2.57315e+06
# [489]	train-rmse:1.59768e+06	test-rmse:2.57329e+06
# [490]	train-rmse:1.59659e+06	test-rmse:2.57306e+06
# [491]	train-rmse:1.59576e+06	test-rmse:2.57311e+06
# [492]	train-rmse:1.595e+06	test-rmse:2.57315e+06
# [493]	train-rmse:1.59403e+06	test-rmse:2.57305e+06
# [494]	train-rmse:1.59308e+06	test-rmse:2.57324e+06
# [495]	train-rmse:1.59215e+06	test-rmse:2.57311e+06
# [496]	train-rmse:1.59153e+06	test-rmse:2.57323e+06
# [497]	train-rmse:1.59075e+06	test-rmse:2.57324e+06
# [498]	train-rmse:1.58995e+06	test-rmse:2.57327e+06
# [499]	train-rmse:1.58937e+06	test-rmse:2.57335e+06
# [500]	train-rmse:1.5888e+06	test-rmse:2.57344e+06
# [501]	train-rmse:1.58768e+06	test-rmse:2.57363e+06
# [502]	train-rmse:1.58706e+06	test-rmse:2.57359e+06
# [503]	train-rmse:1.58605e+06	test-rmse:2.57368e+06
# [504]	train-rmse:1.58525e+06	test-rmse:2.57371e+06
# [505]	train-rmse:1.58454e+06	test-rmse:2.57365e+06
# [506]	train-rmse:1.58354e+06	test-rmse:2.57361e+06
# [507]	train-rmse:1.5827e+06	test-rmse:2.57325e+06
# [508]	train-rmse:1.58155e+06	test-rmse:2.57327e+06
# [509]	train-rmse:1.58074e+06	test-rmse:2.57327e+06
# [510]	train-rmse:1.57988e+06	test-rmse:2.57338e+06
# [511]	train-rmse:1.579e+06	test-rmse:2.57354e+06
# [512]	train-rmse:1.57833e+06	test-rmse:2.5732e+06
# [513]	train-rmse:1.5772e+06	test-rmse:2.57288e+06
# [514]	train-rmse:1.57646e+06	test-rmse:2.57275e+06
# [515]	train-rmse:1.57541e+06	test-rmse:2.57287e+06
# [516]	train-rmse:1.57447e+06	test-rmse:2.57285e+06
# [517]	train-rmse:1.57359e+06	test-rmse:2.57279e+06
# [518]	train-rmse:1.57293e+06	test-rmse:2.57265e+06
# [519]	train-rmse:1.57194e+06	test-rmse:2.57265e+06
# [520]	train-rmse:1.57099e+06	test-rmse:2.57271e+06
# [521]	train-rmse:1.57022e+06	test-rmse:2.57255e+06
# [522]	train-rmse:1.56942e+06	test-rmse:2.57238e+06
# [523]	train-rmse:1.56863e+06	test-rmse:2.57251e+06
# [524]	train-rmse:1.5676e+06	test-rmse:2.57257e+06
# [525]	train-rmse:1.56687e+06	test-rmse:2.57257e+06
# [526]	train-rmse:1.56628e+06	test-rmse:2.57273e+06
# [527]	train-rmse:1.56544e+06	test-rmse:2.57293e+06
# [528]	train-rmse:1.56493e+06	test-rmse:2.57305e+06
# [529]	train-rmse:1.56396e+06	test-rmse:2.57306e+06
# [530]	train-rmse:1.5632e+06	test-rmse:2.57319e+06
# [531]	train-rmse:1.56242e+06	test-rmse:2.57312e+06
# [532]	train-rmse:1.56159e+06	test-rmse:2.57328e+06
# [533]	train-rmse:1.56099e+06	test-rmse:2.57325e+06
# [534]	train-rmse:1.56028e+06	test-rmse:2.57311e+06
# [535]	train-rmse:1.55978e+06	test-rmse:2.57311e+06
# [536]	train-rmse:1.55904e+06	test-rmse:2.57309e+06
# [537]	train-rmse:1.55805e+06	test-rmse:2.5733e+06
# [538]	train-rmse:1.5573e+06	test-rmse:2.57324e+06
# [539]	train-rmse:1.55642e+06	test-rmse:2.57312e+06
# [540]	train-rmse:1.55592e+06	test-rmse:2.57302e+06
# [541]	train-rmse:1.5553e+06	test-rmse:2.57296e+06
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8ea820ae0dc8> in <module>()
#      72 #num_boost_round = 489
#      73
# ---> 74 model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=num_boost_round)
#      75
#      76 fig, ax = plt.subplots(1, 1, figsize=(8, 16))
#
# NameError: name 'num_boost_round' is not defined
